# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities: cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 622

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | geraldton
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | constitucion
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | porto novo
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | klaksvik
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 1 | skovorodino
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | namibe
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | lyantonde
# Processing Record 25 of Set 1 | irituia
# Processing Record 26 of Set 1 | zhigansk
# Processing Record 27 of Set 1 | ruston
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | xaghra
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | cabo san lucas
# Processing Record 33 of Set 1 | marfino
# Processing Record 34 of Set 1 | nago
# Processing Record 35 of Set 1 | mareeba
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | portland
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | chita
# Processing Record 45 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 1 | half moon bay
# Processing Record 49 of Set 1 | maragogi
# Processing Record 50 of Set 1 | abu samrah
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | faanui
# Processing Record 3 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | sechura
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | port lincoln
# Processing Record 8 of Set 2 | zinder
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | saint anthony
# Processing Record 11 of Set 2 | singaraja
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | aklavik
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | port macquarie
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | ahipara
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | singaparna
# Processing Record 20 of Set 2 | kalmunai
# Processing Record 21 of Set 2 | hami
# Processing Record 22 of Set 2 | santa cruz
# Processing Record 23 of Set 2 | torbay
# Processing Record 24 of Set 2 | karratha
# Processing Record 25 of Set 2 | shelburne
# Processing Record 26 of Set 2 | san quintin
# Processing Record 27 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 2 | salinopolis
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | nadapuram
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | aksarayskiy
# Processing Record 35 of Set 2 | comonfort
# Processing Record 36 of Set 2 | arman
# Processing Record 37 of Set 2 | salamiyah
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | hobyo
# Processing Record 41 of Set 2 | valparaiso
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | gorontalo
# Processing Record 44 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | ushuaia
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | lorengau
# Processing Record 50 of Set 2 | paucartambo
# City not found. Skipping...
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | bollnas
# Processing Record 3 of Set 3 | topolobampo
# Processing Record 4 of Set 3 | tarare
# Processing Record 5 of Set 3 | camana
# Processing Record 6 of Set 3 | tazovskiy
# Processing Record 7 of Set 3 | namatanai
# Processing Record 8 of Set 3 | broome
# Processing Record 9 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | luganville
# Processing Record 12 of Set 3 | markova
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | port augusta
# Processing Record 15 of Set 3 | kapaa
# Processing Record 16 of Set 3 | tecoanapa
# Processing Record 17 of Set 3 | copiapo
# Processing Record 18 of Set 3 | kasane
# Processing Record 19 of Set 3 | cape town
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | hasaki
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | gubkinskiy
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | czechowice-dziedzice
# Processing Record 26 of Set 3 | rajnagar
# Processing Record 27 of Set 3 | suao
# City not found. Skipping...
# Processing Record 28 of Set 3 | atuona
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | cauquenes
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | kutum
# Processing Record 33 of Set 3 | kalabo
# Processing Record 34 of Set 3 | brae
# Processing Record 35 of Set 3 | diffa
# Processing Record 36 of Set 3 | aksarka
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | tanggu
# Processing Record 39 of Set 3 | kavaratti
# Processing Record 40 of Set 3 | broken hill
# Processing Record 41 of Set 3 | homer
# Processing Record 42 of Set 3 | butaritari
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | millau
# Processing Record 45 of Set 3 | touros
# Processing Record 46 of Set 3 | leh
# Processing Record 47 of Set 3 | dovers
# Processing Record 48 of Set 3 | mochalishche
# Processing Record 49 of Set 3 | samarai
# Processing Record 50 of Set 3 | werda
# Processing Record 1 of Set 4 | ixtapa
# Processing Record 2 of Set 4 | itoman
# Processing Record 3 of Set 4 | kuminskiy
# Processing Record 4 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 4 | mount isa
# Processing Record 6 of Set 4 | yerbogachen
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | te anau
# Processing Record 9 of Set 4 | pokhara
# Processing Record 10 of Set 4 | ambilobe
# Processing Record 11 of Set 4 | petauke
# Processing Record 12 of Set 4 | batemans bay
# Processing Record 13 of Set 4 | juneau
# Processing Record 14 of Set 4 | chifeng
# Processing Record 15 of Set 4 | rusape
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | kruisfontein
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | hofn
# Processing Record 20 of Set 4 | aswan
# Processing Record 21 of Set 4 | olafsvik
# Processing Record 22 of Set 4 | iwanai
# Processing Record 23 of Set 4 | puri
# Processing Record 24 of Set 4 | ponta do sol
# Processing Record 25 of Set 4 | rundu
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | bejar
# Processing Record 28 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 4 | clarksburg
# Processing Record 30 of Set 4 | bahia blanca
# Processing Record 31 of Set 4 | sawtell
# Processing Record 32 of Set 4 | saint-francois
# Processing Record 33 of Set 4 | korla
# Processing Record 34 of Set 4 | stanovoye
# Processing Record 35 of Set 4 | havelock
# Processing Record 36 of Set 4 | zhuhai
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | wajima
# Processing Record 39 of Set 4 | saskylakh
# Processing Record 40 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 4 | juegang
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | johnston
# Processing Record 44 of Set 4 | victoria
# Processing Record 45 of Set 4 | hithadhoo
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | zlitan
# Processing Record 48 of Set 4 | kargasok
# Processing Record 49 of Set 4 | ojinaga
# Processing Record 50 of Set 4 | raudeberg
# Processing Record 1 of Set 5 | longyearbyen
# Processing Record 2 of Set 5 | carutapera
# Processing Record 3 of Set 5 | tamasopo
# Processing Record 4 of Set 5 | prigoria
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | san andres del rabanedo
# Processing Record 7 of Set 5 | sakaiminato
# Processing Record 8 of Set 5 | ponta delgada
# Processing Record 9 of Set 5 | asau
# Processing Record 10 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | notodden
# Processing Record 13 of Set 5 | ewa beach
# Processing Record 14 of Set 5 | jacareacanga
# Processing Record 15 of Set 5 | bonavista
# Processing Record 16 of Set 5 | erzin
# Processing Record 17 of Set 5 | cururupu
# Processing Record 18 of Set 5 | vardo
# Processing Record 19 of Set 5 | aleksandrovskiy zavod
# Processing Record 20 of Set 5 | souillac
# Processing Record 21 of Set 5 | batagay-alyta
# Processing Record 22 of Set 5 | leeston
# Processing Record 23 of Set 5 | ilo
# Processing Record 24 of Set 5 | dalvik
# Processing Record 25 of Set 5 | muros
# Processing Record 26 of Set 5 | hovd
# Processing Record 27 of Set 5 | ahuimanu
# Processing Record 28 of Set 5 | leningradskiy
# Processing Record 29 of Set 5 | deputatskiy
# Processing Record 30 of Set 5 | manali
# Processing Record 31 of Set 5 | tura
# Processing Record 32 of Set 5 | sorland
# Processing Record 33 of Set 5 | tiznit
# Processing Record 34 of Set 5 | bardiyah
# Processing Record 35 of Set 5 | pittsfield
# Processing Record 36 of Set 5 | scarborough
# Processing Record 37 of Set 5 | hervey bay
# Processing Record 38 of Set 5 | mizdah
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | pangnirtung
# Processing Record 41 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 5 | ostrovnoy
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | puerto leguizamo
# Processing Record 45 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 5 | klyuchi
# Processing Record 47 of Set 5 | olinda
# Processing Record 48 of Set 5 | lebu
# Processing Record 49 of Set 5 | bengkulu
# Processing Record 50 of Set 5 | onguday
# Processing Record 1 of Set 6 | san ramon de la nueva oran
# Processing Record 2 of Set 6 | lebedinyy
# Processing Record 3 of Set 6 | mackenzie
# Processing Record 4 of Set 6 | wladyslawowo
# Processing Record 5 of Set 6 | moree
# Processing Record 6 of Set 6 | krasnozerskoye
# Processing Record 7 of Set 6 | hit
# Processing Record 8 of Set 6 | santa maria
# Processing Record 9 of Set 6 | galesong
# Processing Record 10 of Set 6 | ulyanovsk
# Processing Record 11 of Set 6 | bagdarin
# Processing Record 12 of Set 6 | gushikawa
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | husavik
# Processing Record 15 of Set 6 | alpine
# Processing Record 16 of Set 6 | cooma
# Processing Record 17 of Set 6 | orthez
# Processing Record 18 of Set 6 | ugoofaaru
# Processing Record 19 of Set 6 | griffith
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | djenne
# Processing Record 22 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 23 of Set 6 | outjo
# Processing Record 24 of Set 6 | pacifica
# Processing Record 25 of Set 6 | luanda
# Processing Record 26 of Set 6 | talesh
# City not found. Skipping...
# Processing Record 27 of Set 6 | san policarpo
# Processing Record 28 of Set 6 | dunedin
# Processing Record 29 of Set 6 | san cristobal
# Processing Record 30 of Set 6 | sao filipe
# Processing Record 31 of Set 6 | oistins
# Processing Record 32 of Set 6 | luena
# Processing Record 33 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 6 | henties bay
# Processing Record 35 of Set 6 | flinders
# Processing Record 36 of Set 6 | ola
# Processing Record 37 of Set 6 | ezequiel montes
# Processing Record 38 of Set 6 | mizque
# Processing Record 39 of Set 6 | xai-xai
# Processing Record 40 of Set 6 | bathsheba
# Processing Record 41 of Set 6 | ginir
# Processing Record 42 of Set 6 | vysokogornyy
# Processing Record 43 of Set 6 | manacor
# Processing Record 44 of Set 6 | obera
# Processing Record 45 of Set 6 | rocky mountain house
# Processing Record 46 of Set 6 | rassvet
# Processing Record 47 of Set 6 | sartell
# Processing Record 48 of Set 6 | pa sang
# Processing Record 49 of Set 6 | byron bay
# Processing Record 50 of Set 6 | kaitangata
# Processing Record 1 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 2 of Set 7 | watertown
# Processing Record 3 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 7 | teya
# Processing Record 5 of Set 7 | iqaluit
# Processing Record 6 of Set 7 | pevek
# Processing Record 7 of Set 7 | mixtequilla
# City not found. Skipping...
# Processing Record 8 of Set 7 | viedma
# Processing Record 9 of Set 7 | coihaique
# Processing Record 10 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 7 | jiuquan
# Processing Record 12 of Set 7 | quelimane
# Processing Record 13 of Set 7 | tarauaca
# Processing Record 14 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | kaniama
# Processing Record 16 of Set 7 | guerrero negro
# Processing Record 17 of Set 7 | pasighat
# Processing Record 18 of Set 7 | ibaiti
# Processing Record 19 of Set 7 | gizo
# Processing Record 20 of Set 7 | la romana
# Processing Record 21 of Set 7 | itarema
# Processing Record 22 of Set 7 | kissidougou
# Processing Record 23 of Set 7 | rosarito
# Processing Record 24 of Set 7 | dunn
# Processing Record 25 of Set 7 | castlemaine
# Processing Record 26 of Set 7 | parkersburg
# Processing Record 27 of Set 7 | yar-sale
# Processing Record 28 of Set 7 | grand gaube
# Processing Record 29 of Set 7 | suhbaatar
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 7 | matagami
# Processing Record 32 of Set 7 | kahului
# Processing Record 33 of Set 7 | genhe
# Processing Record 34 of Set 7 | rock falls
# Processing Record 35 of Set 7 | riyadh
# Processing Record 36 of Set 7 | khani
# Processing Record 37 of Set 7 | iguape
# Processing Record 38 of Set 7 | lavrentiya
# Processing Record 39 of Set 7 | maamba
# Processing Record 40 of Set 7 | port-gentil
# Processing Record 41 of Set 7 | salalah
# Processing Record 42 of Set 7 | qasigiannguit
# Processing Record 43 of Set 7 | staryy biser
# City not found. Skipping...
# Processing Record 44 of Set 7 | bara
# Processing Record 45 of Set 7 | gornyy
# Processing Record 46 of Set 7 | maniitsoq
# Processing Record 47 of Set 7 | gat
# Processing Record 48 of Set 7 | puerto escondido
# Processing Record 49 of Set 7 | port hawkesbury
# Processing Record 50 of Set 7 | soyo
# Processing Record 1 of Set 8 | airai
# Processing Record 2 of Set 8 | codrington
# Processing Record 3 of Set 8 | kondinskoye
# Processing Record 4 of Set 8 | la libertad
# Processing Record 5 of Set 8 | yulara
# Processing Record 6 of Set 8 | gillette
# Processing Record 7 of Set 8 | daru
# Processing Record 8 of Set 8 | baykit
# Processing Record 9 of Set 8 | kolondieba
# Processing Record 10 of Set 8 | maibong
# Processing Record 11 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 8 | dingle
# Processing Record 13 of Set 8 | enderby
# Processing Record 14 of Set 8 | bilma
# Processing Record 15 of Set 8 | johnson city
# Processing Record 16 of Set 8 | nalut
# Processing Record 17 of Set 8 | ekhabi
# Processing Record 18 of Set 8 | waipawa
# Processing Record 19 of Set 8 | ancud
# Processing Record 20 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 21 of Set 8 | liverpool
# Processing Record 22 of Set 8 | gondar
# Processing Record 23 of Set 8 | victoria point
# Processing Record 24 of Set 8 | ous
# Processing Record 25 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 8 | cap malheureux
# Processing Record 28 of Set 8 | port pirie
# Processing Record 29 of Set 8 | loukhi
# Processing Record 30 of Set 8 | montana
# Processing Record 31 of Set 8 | skibbereen
# Processing Record 32 of Set 8 | severnoye
# Processing Record 33 of Set 8 | pingliang
# Processing Record 34 of Set 8 | alyangula
# Processing Record 35 of Set 8 | richards bay
# Processing Record 36 of Set 8 | krasnoselkup
# Processing Record 37 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 8 | idah
# Processing Record 39 of Set 8 | taltal
# Processing Record 40 of Set 8 | fairview
# Processing Record 41 of Set 8 | havre-saint-pierre
# Processing Record 42 of Set 8 | matara
# Processing Record 43 of Set 8 | bagar
# Processing Record 44 of Set 8 | muhos
# Processing Record 45 of Set 8 | cap-aux-meules
# Processing Record 46 of Set 8 | kandalaksha
# Processing Record 47 of Set 8 | yeppoon
# Processing Record 48 of Set 8 | kudahuvadhoo
# Processing Record 49 of Set 8 | vestmannaeyjar
# Processing Record 50 of Set 8 | mercedes
# Processing Record 1 of Set 9 | mbuguni
# Processing Record 2 of Set 9 | moengo
# Processing Record 3 of Set 9 | vostok
# Processing Record 4 of Set 9 | ulu tiram
# Processing Record 5 of Set 9 | manacapuru
# Processing Record 6 of Set 9 | stornoway
# Processing Record 7 of Set 9 | kieta
# Processing Record 8 of Set 9 | seryshevo
# Processing Record 9 of Set 9 | bereda
# Processing Record 10 of Set 9 | kamenka
# Processing Record 11 of Set 9 | prince rupert
# Processing Record 12 of Set 9 | saurimo
# Processing Record 13 of Set 9 | malanje
# Processing Record 14 of Set 9 | novichikha
# Processing Record 15 of Set 9 | ust-maya
# Processing Record 16 of Set 9 | acin
# City not found. Skipping...
# Processing Record 17 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 9 | mezen
# Processing Record 19 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 9 | toora-khem
# Processing Record 21 of Set 9 | camacha
# Processing Record 22 of Set 9 | acajutla
# Processing Record 23 of Set 9 | shache
# Processing Record 24 of Set 9 | sisimiut
# Processing Record 25 of Set 9 | curup
# Processing Record 26 of Set 9 | nome
# Processing Record 27 of Set 9 | palkaka
# City not found. Skipping...
# Processing Record 28 of Set 9 | stephenville
# Processing Record 29 of Set 9 | le port
# Processing Record 30 of Set 9 | palmer
# Processing Record 31 of Set 9 | rio sereno
# Processing Record 32 of Set 9 | mana
# Processing Record 33 of Set 9 | college
# Processing Record 34 of Set 9 | novo aripuana
# Processing Record 35 of Set 9 | yichun
# Processing Record 36 of Set 9 | kon tum
# Processing Record 37 of Set 9 | limbe
# Processing Record 38 of Set 9 | kamennogorsk
# Processing Record 39 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 9 | sao miguel do araguaia
# Processing Record 41 of Set 9 | talaya
# Processing Record 42 of Set 9 | kysyl-syr
# Processing Record 43 of Set 9 | vegreville
# Processing Record 44 of Set 9 | lyaskelya
# Processing Record 45 of Set 9 | mae hong son
# Processing Record 46 of Set 9 | pisco
# Processing Record 47 of Set 9 | son la
# Processing Record 48 of Set 9 | togur
# Processing Record 49 of Set 9 | road town
# Processing Record 50 of Set 9 | belyy yar
# Processing Record 1 of Set 10 | yeniseysk
# Processing Record 2 of Set 10 | poum
# Processing Record 3 of Set 10 | kupang
# Processing Record 4 of Set 10 | buin
# Processing Record 5 of Set 10 | maryborough
# Processing Record 6 of Set 10 | wilmington
# Processing Record 7 of Set 10 | bulgan
# Processing Record 8 of Set 10 | gloucester
# Processing Record 9 of Set 10 | kemi
# Processing Record 10 of Set 10 | kemise
# Processing Record 11 of Set 10 | umm kaddadah
# Processing Record 12 of Set 10 | karpathos
# Processing Record 13 of Set 10 | kiomboi
# Processing Record 14 of Set 10 | plettenberg bay
# Processing Record 15 of Set 10 | vieques
# Processing Record 16 of Set 10 | fairbanks
# Processing Record 17 of Set 10 | beringovskiy
# Processing Record 18 of Set 10 | bandarbeyla
# Processing Record 19 of Set 10 | caravelas
# Processing Record 20 of Set 10 | kijang
# Processing Record 21 of Set 10 | sangar
# Processing Record 22 of Set 10 | yanam
# Processing Record 23 of Set 10 | sabzevar
# Processing Record 24 of Set 10 | pangody
# Processing Record 25 of Set 10 | nouadhibou
# Processing Record 26 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 27 of Set 10 | nishihara
# Processing Record 28 of Set 10 | sampit
# Processing Record 29 of Set 10 | san rafael
# Processing Record 30 of Set 10 | sisophon
# Processing Record 31 of Set 10 | alta floresta
# Processing Record 32 of Set 10 | vizinga
# Processing Record 33 of Set 10 | mishan
# Processing Record 34 of Set 10 | norilsk
# Processing Record 35 of Set 10 | chandbali
# Processing Record 36 of Set 10 | sambava
# Processing Record 37 of Set 10 | coquimbo
# Processing Record 38 of Set 10 | ondangwa
# Processing Record 39 of Set 10 | santa rita
# Processing Record 40 of Set 10 | camacari
# Processing Record 41 of Set 10 | panaba
# Processing Record 42 of Set 10 | viransehir
# Processing Record 43 of Set 10 | urucui
# Processing Record 44 of Set 10 | taoudenni
# Processing Record 45 of Set 10 | opuwo
# Processing Record 46 of Set 10 | manta
# Processing Record 47 of Set 10 | puerto narino
# Processing Record 48 of Set 10 | laguna
# Processing Record 49 of Set 10 | grindavik
# Processing Record 50 of Set 10 | troitsko-pechorsk
# Processing Record 1 of Set 11 | davila
# Processing Record 2 of Set 11 | sinnamary
# Processing Record 3 of Set 11 | margate
# Processing Record 4 of Set 11 | sioux lookout
# Processing Record 5 of Set 11 | hirara
# Processing Record 6 of Set 11 | pangai
# Processing Record 7 of Set 11 | macusani
# Processing Record 8 of Set 11 | northam
# Processing Record 9 of Set 11 | avera
# Processing Record 10 of Set 11 | mitsamiouli
# Processing Record 11 of Set 11 | sri aman
# Processing Record 12 of Set 11 | nurota
# Processing Record 13 of Set 11 | irbeyskoye
# Processing Record 14 of Set 11 | filadelfia
# Processing Record 15 of Set 11 | iquique
# Processing Record 16 of Set 11 | tautira
# Processing Record 17 of Set 11 | agropoli
# Processing Record 18 of Set 11 | mogadishu
# Processing Record 19 of Set 11 | den helder
# Processing Record 20 of Set 11 | kagadi
# Processing Record 21 of Set 11 | grants
# Processing Record 22 of Set 11 | kirakira
# Processing Record 23 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 24 of Set 11 | hauterive
# Processing Record 25 of Set 11 | doha
# Processing Record 26 of Set 11 | wagga wagga
# Processing Record 27 of Set 11 | casablanca
# Processing Record 28 of Set 11 | fos-sur-mer
# Processing Record 29 of Set 11 | staraya mayna
# Processing Record 30 of Set 11 | nchelenge
# Processing Record 31 of Set 11 | kashi
# Processing Record 32 of Set 11 | odweyne
# Processing Record 33 of Set 11 | jhalida
# Processing Record 34 of Set 11 | wasilla
# Processing Record 35 of Set 11 | meulaboh
# Processing Record 36 of Set 11 | proletariy
# Processing Record 37 of Set 11 | beloha
# Processing Record 38 of Set 11 | quthing
# Processing Record 39 of Set 11 | sydney
# Processing Record 40 of Set 11 | bambanglipuro
# Processing Record 41 of Set 11 | jonkoping
# Processing Record 42 of Set 11 | peleduy
# Processing Record 43 of Set 11 | graaff-reinet
# Processing Record 44 of Set 11 | monrovia
# Processing Record 45 of Set 11 | hambantota
# Processing Record 46 of Set 11 | tessalit
# Processing Record 47 of Set 11 | okhotsk
# Processing Record 48 of Set 11 | tilichiki
# Processing Record 49 of Set 11 | paamiut
# Processing Record 50 of Set 11 | carauari
# Processing Record 1 of Set 12 | lata
# Processing Record 2 of Set 12 | port hardy
# Processing Record 3 of Set 12 | jiangyou
# Processing Record 4 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 12 | tarko-sale
# Processing Record 6 of Set 12 | lompoc
# Processing Record 7 of Set 12 | ambon
# Processing Record 8 of Set 12 | tukrah
# Processing Record 9 of Set 12 | mehamn
# Processing Record 10 of Set 12 | xining
# Processing Record 11 of Set 12 | saint-louis
# Processing Record 12 of Set 12 | la asuncion
# Processing Record 13 of Set 12 | sistranda
# Processing Record 14 of Set 12 | ulagan
# Processing Record 15 of Set 12 | thinadhoo
# Processing Record 16 of Set 12 | ligayan
# Processing Record 17 of Set 12 | dwarka
# Processing Record 18 of Set 12 | kanniyakumari
# Processing Record 19 of Set 12 | natal
# Processing Record 20 of Set 12 | lucapa
# Processing Record 21 of Set 12 | cobija
# Processing Record 22 of Set 12 | saint-pierre
# Processing Record 23 of Set 12 | meiganga
# Processing Record 24 of Set 12 | kidal
# Processing Record 25 of Set 12 | vermillion
# Processing Record 26 of Set 12 | esperance
# Processing Record 27 of Set 12 | teguldet
# Processing Record 28 of Set 12 | vanavara
# Processing Record 29 of Set 12 | bideford
# Processing Record 30 of Set 12 | ghanzi
# Processing Record 31 of Set 12 | abu kamal
# Processing Record 32 of Set 12 | mallow
# Processing Record 33 of Set 12 | hamilton
# Processing Record 34 of Set 12 | himare
# Processing Record 35 of Set 12 | warrington
# Processing Record 36 of Set 12 | marsa matruh
# Processing Record 37 of Set 12 | mehriz
# Processing Record 38 of Set 12 | egvekinot
# Processing Record 39 of Set 12 | tirano
# Processing Record 40 of Set 12 | nanortalik
# Processing Record 41 of Set 12 | tuckahoe
# Processing Record 42 of Set 12 | necochea
# Processing Record 43 of Set 12 | qui nhon
# Processing Record 44 of Set 12 | punta gorda
# Processing Record 45 of Set 12 | tole
# Processing Record 46 of Set 12 | zhangjiakou
# Processing Record 47 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 12 | seymchan
# Processing Record 49 of Set 12 | la paz
# Processing Record 50 of Set 12 | trairi
# Processing Record 1 of Set 13 | barahona
# Processing Record 2 of Set 13 | kulai
# Processing Record 3 of Set 13 | boyolangu
# Processing Record 4 of Set 13 | pakdasht
# Processing Record 5 of Set 13 | la ronge
# Processing Record 6 of Set 13 | surskoye
# Processing Record 7 of Set 13 | aljezur
# Processing Record 8 of Set 13 | rawson
# Processing Record 9 of Set 13 | manica
# Processing Record 10 of Set 13 | pacific grove
# Processing Record 11 of Set 13 | culaman
# Processing Record 12 of Set 13 | kiunga
# Processing Record 13 of Set 13 | antofagasta
# Processing Record 14 of Set 13 | mayya
# Processing Record 15 of Set 13 | vanimo
# Processing Record 16 of Set 13 | booue
# Processing Record 17 of Set 13 | pemberton
# Processing Record 18 of Set 13 | san patricio
# Processing Record 19 of Set 13 | muzhi
# Processing Record 20 of Set 13 | sisak
# Processing Record 21 of Set 13 | sibiti
# Processing Record 22 of Set 13 | kiruna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Geraldton -28.7667  114.6000     48.61       100         100
# 1  Sao Joao Da Barra -21.6403  -41.0511     70.81        91          46
# 2              Vaini -21.2000 -175.2000     78.96        94          75
# 3       Constitucion -35.3333  -72.4167     51.91        73          88
# 4            Qaanaaq  77.4840  -69.3632     38.48        58           0
# 5         Porto Novo   6.4965    2.6036     74.52        84          46
# 6              Tiksi  71.6872  128.8694     57.47        72          66
# 7     Saint-Philippe -21.3585   55.7679     67.59        77          66
# 8             Albany  42.6001  -73.9662     81.05        62          39
# 9       Punta Arenas -53.1500  -70.9167     42.12        86          96
#
#    Wind Speed Country Current Description
# 0        5.75      AU     overcast clouds
# 1       11.32      BR    scattered clouds
# 2       13.80      TO       broken clouds
# 3        7.99      CL     overcast clouds
# 4        2.62      GL           clear sky
# 5        8.46      BJ    scattered clouds
# 6       14.76      RU       broken clouds
# 7       15.48      RE       broken clouds
# 8        9.55      US    scattered clouds
# 9        9.71      CL     overcast clouds

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Geraldton      AU -28.7667  114.6000     48.61       100
# 1    Sao Joao Da Barra      BR -21.6403  -41.0511     70.81        91
# 2                Vaini      TO -21.2000 -175.2000     78.96        94
# 3         Constitucion      CL -35.3333  -72.4167     51.91        73
# 4              Qaanaaq      GL  77.4840  -69.3632     38.48        58
# ..                 ...     ...      ...       ...       ...       ...
# 570       San Patricio      US  28.0170  -97.5169     95.72        45
# 571              Muzhi      RU  65.3667   64.6667     54.34        65
# 572              Sisak      HR  45.4661   16.3783     67.98        84
# 573             Sibiti      CG  -3.6819   13.3499     72.18        62
# 574             Kiruna      SE  67.8557   20.2251     49.12        93
#
#      Cloudiness  Wind Speed Current Description
# 0           100        5.75     overcast clouds
# 1            46       11.32    scattered clouds
# 2            75       13.80       broken clouds
# 3            88        7.99     overcast clouds
# 4             0        2.62           clear sky
# ..          ...         ...                 ...
# 570          51       14.67       broken clouds
# 571          93        6.33     overcast clouds
# 572          30        1.92    scattered clouds
# 573          22        3.33          few clouds
# 574         100        0.00     overcast clouds
#
# [575 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPY_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
